# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/netra_model/pytorch/default/1/best 1.pt
# /kaggle/input/netra-1000/1000_jpg_images/4711c4f642f5b59d9371590bdcca7ed186abf391_000017.jpg
# /kaggle/input/netra-1000/1000_jpg_images/3cdcba434df0c2658dab4caefde7dec424ac5d31_000029.jpg
# /kaggle/input/netra-1000/1000_jpg_images/d67eb8b10febae77139439f1cad06f8475ce60a1_000017.jpg
# /kaggle/input/netra-1000/1000_jpg_images/060ad92c4534fcd8e6c59571ea20cf3777790051_000029.jpg
# /kaggle/input/netra-1000/1000_jpg_images/cc0b6fac6c72d12e9140abe38fa4f8871f110651_000017.jpg
# /kaggle/input/netra-1000/1000_jpg_images/0c98bf20c40e89a87969812db7101462f32afbc1_000017.jpg
# /kaggle/input/netra-1000/1000_jpg_images/bde5a1011b18ebae7c2de01ec5cbbb3fb4570b31_000017.jpg
# /kaggle/input/netra-1000/1000_jpg_images/02a4e311621797057953b259b5adceb3d28fe321_000010.jpg
# /kaggle/input/netra-1000/1000_jpg_images/2ef79b433f670aba1db246955806052ae4a25a21_000017.jpg
# ...

# %%
# Clone the YOLOv5 repository
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17511, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 17511 (delta 5), reused 0 (delta 0), pack-reused 17491 (from 3)
# Receiving objects: 100% (17511/17511), 16.62 MiB | 31.34 MiB/s, done.
# Resolving deltas: 100% (12000/12000), done.

# %%
cd /kaggle/working/yolov5
# Out:
# /kaggle/working/yolov5

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.8 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 32.0 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.4 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 2.9 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 74.5 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 55.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.9.41
#     Uninstalling nvidia-nvjitlink-cu12-12.9.41:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.9.41
# ...

# %%
# !pip install aimet-torch
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 60.7 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.3/170.3 kB 13.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 661.0/661.0 kB 40.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.0/119.0 kB 10.8 MB/s eta 0:00:00
# ...

# %%
import torch
from aimet_torch.quantsim import QuantizationSimModel
# Out:
# <frozen abc>:106: FutureWarning: `NLLLoss2d` has been deprecated. Please use `NLLLoss` instead as a drop-in replacement and see https://pytorch.org/docs/main/nn.html#torch.nn.NLLLoss for more details.
# 2025-07-06 18:56:14.333731: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751828174.512995      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751828174.570293      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
from utils.torch_utils import select_device
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
weights_path = "/kaggle/input/netra_model/pytorch/default/1/best 1.pt" #replace with the model weights path

imgsz = 640
batch_size = 32
device = select_device('')
# Out:
# YOLOv5 🚀 v7.0-422-g2540fd4c Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)

# %%
from models.experimental import attempt_load

# %%
model = attempt_load(weights_path).eval()  # YOLOv5s
model.to(device)
# Out:
# Fusing layers...
# YOLOv5s summary: 157 layers, 7047883 parameters, 0 gradients, 15.9 GFLOPs
# DetectionModel(
#   (model): Sequential(
#     (0): Conv(
#       (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#       (act): SiLU(inplace=True)
#     )
#     (1): Conv(
#       (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (act): SiLU(inplace=True)
#     )
#     (2): C3(
#       (cv1): Conv(
#         (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (cv3): Conv(
#         (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
# ...

# %%
import torch
from torch.utils.data import Dataset, DataLoader
from pathlib import Path
from PIL import Image
import torchvision.transforms as T

class ImageFolderSimple(Dataset):
    def __init__(self, image_dir, img_size=640):
        self.image_paths = list(Path(image_dir).glob("*.jpg"))
        self.transform = T.Compose([
            T.Resize((img_size, img_size)),
            T.ToTensor(),  # Converts to [0,1]
        ])

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        image = Image.open(img_path).convert("RGB")
        return self.transform(image)

# Create loader
val_dataset = ImageFolderSimple("/kaggle/input/netra-1000/1000_jpg_images", img_size=640) #replace the path to image data
val_loader = DataLoader(val_dataset, batch_size=4, shuffle=False, num_workers=2)

# %%
from aimet_torch.quantsim import QuantizationSimModel
from aimet_torch.batch_norm_fold import fold_all_batch_norms
from aimet_common.defs import QuantScheme
from aimet_common.quantsim_config.utils import get_path_for_per_channel_config

# %%
model.cpu().float()  # <-- FIXED: force model to float32 before folding

dummy_input = torch.randn(1, 3, imgsz, imgsz)  # float32 dummy input
#_ = fold_all_batch_norms(model, input_shapes=(1, 3, imgsz, imgsz)) --> use model.fuse() instead

# %%
from aimet_torch.v2.nn import QuantizationMixin
from models.common import Concat  # This is YOLOv5's Concat module

@QuantizationMixin.implements(Concat)
class QuantizedConcat(QuantizationMixin, Concat):
    def __quant_init__(self):
        super().__quant_init__()
        self.input_quantizers = torch.nn.ModuleList([None])  # 1 input
        self.output_quantizers = torch.nn.ModuleList([None])  # 1 output

    def forward(self, x):
        # Quantize inputs
        if self.input_quantizers[0]:
            x = self.input_quantizers[0](x)

        with self._patch_quantized_parameters():
            out = super().forward(x)

        # Quantize output
        if self.output_quantizers[0]:
            out = self.output_quantizers[0](out)

        return out

# %%
# Sim model creation
sim = QuantizationSimModel(
    model=model,
    dummy_input=torch.randn(1, 3, imgsz, imgsz),  # must match model input size
    quant_scheme='tf_enhanced',
    rounding_mode='nearest',
    config_file=get_path_for_per_channel_config(),
    default_output_bw=8,
    default_param_bw=8
)
# Out:
# /tmp/ipykernel_35/107455518.py:2: DeprecationWarning: Passing rounding_mode='nearest' is no longer needed and will be deprecated soon in the later versions.
#   sim = QuantizationSimModel(
# /kaggle/working/yolov5/models/yolo.py:101: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if self.dynamic or self.grid[i].shape[2:4] != x[i].shape[2:4]:
# ...

# %%
# Find and freeze optimal encodings candidate for parameters of supported layer(s)/operations(s).
from aimet_torch.seq_mse import  apply_seq_mse, SeqMseParams
params = SeqMseParams(num_batches=4,
                      num_candidates=20,
                      inp_symmetry='symqt',
                      loss_fn='mse')

apply_seq_mse(model=model, sim=sim, data_loader=val_loader, params=params)
# Out:
# 2025-07-06 19:10:33,090 - Utils - INFO - Caching 4 batches from data loader at path location: /tmp/tmpsx5dkziz/cached_dataset

# %%
# --- CALIBRATION (compute encodings) ---
def calibration_forward_pass(model, _):
    model.eval()
    with torch.no_grad():
        for i, img in enumerate(val_loader):
            img = img.float() / 255.0  # Optional if already in [0,1] from ToTensor
            model(img)

# %%
# Compute quantization encodings (this initializes quant params)
sim.compute_encodings(calibration_forward_pass, None)

# %%
sim.export('./models/', 'netra_aimet_quant_seq_mse', dummy_input=torch.randn(1, 3, imgsz, imgsz))
# Out:
# /kaggle/working/yolov5/models/yolo.py:268: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if augment:
# /kaggle/working/yolov5/models/yolo.py:167: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if profile:
# /kaggle/working/yolov5/models/yolo.py:171: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if visualize:
# ...
